# %%
from fastai.vision import *

# %%
classes = ['aedes', 'anopheles', 'culex', 'culiseta', 'mansonia']

# %%
path_img = Path('~/.data/mosquitoes/images').expanduser()

# %%
learn = load_learner(path_img)

# %%
img = open_image('/home/vaisakh/aedes.jpeg'); img
# Out:
# Image (3, 355, 474)

# %%
str(learn.predict(img)[0])
# Out:
# 'aedes'
